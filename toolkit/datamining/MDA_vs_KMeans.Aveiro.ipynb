# %% [markdown]
# # Comparison MDA vs KMeans

# %%
import numpy as np
import pandas as pd
import xarray as xr
from bluemath_tk.datamining.mda import MDA
from bluemath_tk.datamining.kma import KMA
from bluemath_tk.datamining.lhs import LHS

from utils.plotting import plot_variable_combinations

# %% [markdown]
# ## Load Dataset

# %%
data = (
    xr.open_dataset("/workspaces/BlueMath/climate_services/MUSCLE.Aveiro/data/era5_aveiro.nc")
    .rename({"swh": "Hs", "pp1d": "Tp", "mwd": "Dir"})
    .to_dataframe()
    .iloc[::10, :]
    .reset_index()
    .drop(columns=["latitude", "longitude", "time"])
)
data
# Out:
#              Hs         Tp         Dir
# 0      4.233710   7.783655  170.643792
# 1      3.931029  13.985347  214.811325
# 2      4.210661  13.922741  233.840720
# 3      4.045769  14.130647  243.036796
# 4      3.583768  13.645868  250.315649
# ...         ...        ...         ...
# 73630  2.037433  11.260138  297.323308
# 73631  1.970565  11.130574  296.636624
# 73632  2.304654  11.563795  287.248277
# 73633  4.109092  13.685708  308.639865
# 73634  3.883664  13.529025  309.007928
#
# [73635 rows x 3 columns]

# %%
num_centers = 100
dir_vars = ['Dir']

mda = MDA(num_centers=num_centers)
nearest_centroids_idxs, nearest_centroids_df = mda.fit_predict(
    data=data,
    directional_variables=dir_vars,
)
# Out:
# 2025-04-02 10:47:27,562 - MDA - WARNING - Setting self.num_workers to 1. Change it using self.set_num_processors_to_use method.

# %%
vars = ['Hs', 'Tp', 'Dir']  # Lista de variables
sel_mda = mda.centroids[vars]  # Selección de puntos
plot_variable_combinations(mda.data, vars, mda.centroids, labels = 'MDA')
# Out:
# /workspaces/BlueMath/toolkit/datamining/utils/plotting.py:39: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(v1, v2, c=data_color, s=size_point, cmap  = 'rainbow', alpha=0.2)

# %% [markdown]
# ## KMA

# %%
num_centers = 50
dir_vars = ['Dir']

kma = KMA(num_clusters=num_centers)
nearest_centroids_idxs, nearest_centroids_df = kma.fit_predict(
    data=data,
    directional_variables=dir_vars,
)
# Out:
# 2025-04-02 10:47:53,140 - KMA - WARNING - Setting self.num_workers to 1. Change it using self.set_num_processors_to_use method.

# %%
vars = ['Hs', 'Tp', 'Dir']  # Lista de variables
plot_variable_combinations(kma.data, vars, kma.centroids, labels = 'KMA')
# Out:
# /workspaces/BlueMath/toolkit/datamining/utils/plotting.py:39: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(v1, v2, c=data_color, s=size_point, cmap  = 'rainbow', alpha=0.2)

# %% [markdown]
# ## Compare MDA vs KMA

# %%
vars = ['Hs', 'Tp', 'Dir']  # Lista de variables
sel_mda = mda.centroids[vars]  # Selección de puntos
plot_variable_combinations(mda.data, vars, [mda.centroids, kma.centroids], labels = ['MDA', 'KMA'])
# Out:
# /workspaces/BlueMath/toolkit/datamining/utils/plotting.py:39: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(v1, v2, c=data_color, s=size_point, cmap  = 'rainbow', alpha=0.2)

# %% [markdown]
# ### Predict the cluster for a given value using MDA and KMeans

# %%
# Generate a sample data to predict:

data_pred = pd.DataFrame(
    {
        'Hs': [4, 2, 6],
        'Tp': [12, 10, 15],
        'Dir': [90, 350, 280]
    }
)

# %% [markdown]
# ### Using MDA

# %%
print('\nInput data to predict:')
print(data_pred)

print('\nPredicted Cluster:')
print(mda.centroids.iloc[mda.predict(data_pred)[0]])
# Out:
# 2025-04-02 10:48:52,901 - MDA - WARNING - Proposed max custom scaler for Dir_u is lower than datapoint
# Input data to predict:
#    Hs  Tp  Dir
# 0   4  12   90
# 1   2  10  350
# 2   6  15  280
#
# Predicted Cluster:
#           Hs         Tp     Dir_u     Dir_v         Dir
# 30  1.894578  13.862813  0.994653  0.103276   84.072131
# 27  1.197271  11.098099  0.001918  0.999998    0.109871
# 46  7.180992  15.124310 -0.978001  0.208602  282.040463

# %% [markdown]
# ### Using KMeans

# %%
print('\nInput data to predict:')
print(data_pred)

print('\nPredicted Cluster:')
print(kma.centroids.iloc[kma.predict(data_pred)[0].kma_bmus.values])
# Out:
# 2025-04-02 10:48:18,813 - KMA - WARNING - Proposed max custom scaler for Dir_u is lower than datapoint
# Input data to predict:
#    Hs  Tp  Dir
# 0   4  12   90
# 1   2  10  350
# 2   6  15  280
#
# Predicted Cluster:
#           Hs         Tp     Dir_u     Dir_v         Dir
# 24  1.624439   9.732354  0.837163  0.465253   60.936891
# 14  1.548955   8.990288 -0.203028  0.975507  348.243132
# 46  6.254560  15.499816 -0.919918  0.354996  291.101597
