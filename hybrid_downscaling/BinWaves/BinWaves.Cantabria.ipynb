# %%
import xarray as xr

from bluemath_tk.topo_bathy.swan_grid import generate_grid_parameters
from bluemath_tk.waves.binwaves import (
    process_kp_coefficients,
    transform_CAWCR_WS,
)
from bluemath_tk.wrappers.swan.swan_wrapper import SwanModelWrapper
from plotting import binwaves

# %%
# Load GEBCO bathymetry
bathy_data = xr.open_dataset(
    "/home/tausiaj/GitHub-GeoOcean/BlueMath/test_data/bati_tarawa_500m_LONLAT.nc"
)

# %%
binwaves.plot_bathymetry(bathy_data.elevation)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 binwaves.plot_bathymetry(bathy_data.elevation)
#
# File ~/GitHub-GeoOcean/BlueMath_notebooks/plotting/binwaves.py:37, in plot_bathymetry(bathy, min_z, max_z, alpha, figsize, cbar, ax, bathy_lines)
#      34 c1 = colormap_bathy(max_z, min_z)
#      36 # plot bathymetry
# ---> 37 im = ax.pcolorfast(
#      38     bathy.lon.values,
#      39     bathy.lat.values,
#      40     -bathy.values,
#      41     cmap=c1,
#      42     vmax=max_z,
#      43     vmin=min_z,
#      44     zorder=1,
#      45     alpha=alpha,
#      46 )
#      48 ax.contour(bathy.lon.values, bathy.lat.values, -bathy.values, [0], colors="black")
#      50 if bathy_lines:
#
# File ~/miniforge3/envs/bluemath-dev/lib/python3.12/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/bluemath-dev/lib/python3.12/site-packages/matplotlib/axes/_axes.py:6659, in Axes.pcolorfast(self, alpha, norm, cmap, vmin, vmax, colorizer, *args, **kwargs)
#    6657 else:
#    6658     if x.size != nc + 1:
# -> 6659         raise ValueError(
#    6660             f"Length of X ({x.size}) must be one larger than the "
#    6661             f"number of columns in C ({nc})")
#    6662     if y.size != nr + 1:
#    6663         raise ValueError(
#    6664             f"Length of Y ({y.size}) must be one larger than the "
#    6665             f"number of rows in C ({nr})"
#    6666         )
#
# ValueError: Length of X (106) must be one larger than the number of columns in C (87)

# %%
# Generate grid parameters
grid_parameters = generate_grid_parameters(bathy_data)
